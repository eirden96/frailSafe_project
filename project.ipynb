# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
from sklearn.preprocessing import MinMaxScaler
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score

# %%
beacons = pd.read_csv("beacons_dataset.csv", delimiter=';')
clinical = pd.read_csv("clinical_dataset.csv", delimiter=';')

# %%
beacons.head(10)
# Out:
#   part_id   ts_date   ts_time     room
# 0    3089  20170915  06:45:22  Kitchen
# 1    3089  20170915  06:45:33  Bedroom
# 2    3089  20170915  06:45:39  Outdoor
# 3    3089  20170915  06:45:53  Bedroom
# 4    3089  20170915  06:46:09  Outdoor
# 5    3089  20170915  06:46:23  Bedroom
# 6    3089  20170915  06:46:39  Outdoor
# 7    3089  20170915  06:46:53  Bedroom
# 8    3089  20170915  06:47:09  Outdoor
# 9    3089  20170915  06:47:23  Bedroom

# %%
clinical.head()
# Out:
#    part_id      fried gender  age  hospitalization_one_year  \
# 0     1001  Non frail      F   75                         0
# 1     1002  Pre-frail      M   73                         0
# 2     1003  Pre-frail      M   72                         0
# 3     1004      Frail      F   88                         0
# 4     1005  Pre-frail      F   83                         0
#
#    hospitalization_three_years ortho_hypotension           vision  \
# 0                            0                No  Sees moderately
# 1                            1                No  Sees moderately
# 2                            0                No  Sees moderately
# 3                            0                No  Sees moderately
# 4                            4               Yes  Sees moderately
#
#            audition weight_loss  ...  health_rate_comparison  pain_perception  \
# 0        Hears well          No  ...      3 - About the same              4.2
# 1  Hears moderately          No  ...      2 - A little worse              3.3
# 2  Hears moderately          No  ...      3 - About the same              3.4
# 3  Hears moderately          No  ...      3 - About the same              7.3
# 4      Hears poorly          No  ...      3 - About the same              3.0
#
#            activity_regular                                  smoking  \
# 0  > 2 h and < 5 h per week                             Never smoked
# 1  > 2 h and < 5 h per week                             Never smoked
# 2            < 2 h per week  Past smoker (stopped at least 6 months)
# 3            < 2 h per week                             Never smoked
# 4            > 5 h per week                           Current smoker
#
#    alcohol_units  katz_index iadl_grade comorbidities_count  \
# 0            1.0         6.0       31.0                   5
# 1           14.0         6.0       26.0                  12
# 2           21.0         6.0       26.0                   9
# 3           21.0         5.5       20.0                  11
# 4            0.0         6.0       30.0                  12
#
#   comorbidities_significant_count  medication_count
# 0                               0                 5
# 1                               0                 4
# 2                               0                 3
# 3                               0                 8
# 4                               0                 4
#
# [5 rows x 55 columns]

# %%
beacons.columns
# Out:
# Index(['part_id', 'ts_date', 'ts_time', 'room'], dtype='object')

# %%
clinical.columns
# Out:
# Index(['part_id', 'fried', 'gender', 'age', 'hospitalization_one_year',
#        'hospitalization_three_years', 'ortho_hypotension', 'vision',
#        'audition', 'weight_loss', 'exhaustion_score', 'raise_chair_time',
#        'balance_single', 'gait_get_up', 'gait_speed_4m',
#        'gait_optional_binary', 'gait_speed_slower', 'grip_strength_abnormal',
#        'low_physical_activity', 'falls_one_year', 'fractures_three_years',
#        'bmi_score', 'bmi_body_fat', 'waist', 'lean_body_mass',
#        'screening_score', 'cognitive_total_score', 'memory_complain', 'sleep',
#        'mmse_total_score', 'depression_total_score', 'anxiety_perception',
#        'living_alone', 'leisure_out', 'leisure_club', 'social_visits',
#        'social_calls', 'social_phone', 'social_skype', 'social_text',
#        'house_suitable_participant', 'house_suitable_professional',
#        'stairs_number', 'life_quality', 'health_rate',
#        'health_rate_comparison', 'pain_perception', 'activity_regular',
#        'smoking', 'alcohol_units', 'katz_index', 'iadl_grade',
#        'comorbidities_count', 'comorbidities_significant_count',
#        'medication_count'],
#       dtype='object')

# %%
clinical.isnull().sum()
# Out:
# part_id                              0
# fried                                0
# gender                               0
# age                                  0
# hospitalization_one_year             0
# hospitalization_three_years          0
# ortho_hypotension                    0
# vision                               0
# audition                             0
# weight_loss                          2
# exhaustion_score                     0
# raise_chair_time                     1
# balance_single                       1
# gait_get_up                          2
# gait_speed_4m                        0
# gait_optional_binary                 0
# gait_speed_slower                    0
# grip_strength_abnormal               0
# low_physical_activity                0
# falls_one_year                       0
# fractures_three_years                0
# bmi_score                            2
# bmi_body_fat                       133
# waist                                3
# lean_body_mass                     133
# screening_score                      0
# cognitive_total_score               56
# memory_complain                     39
# sleep                                3
# mmse_total_score                     0
# depression_total_score               1
# anxiety_perception                   1
# living_alone                         1
# leisure_out                          1
# leisure_club                         1
# social_visits                        1
# social_calls                         2
# social_phone                         1
# social_skype                         1
# social_text                          2
# house_suitable_participant          98
# house_suitable_professional         98
# stairs_number                       98
# life_quality                         1
# health_rate                          1
# health_rate_comparison               1
# pain_perception                      1
# activity_regular                     2
# smoking                              1
# alcohol_units                        0
# katz_index                           0
# iadl_grade                           1
# comorbidities_count                  0
# comorbidities_significant_count      0
# medication_count                     0
# dtype: int64

# %%
clinical.nunique()
# Out:
# part_id                            540
# fried                                3
# gender                               2
# age                                 27
# hospitalization_one_year             8
# hospitalization_three_years         12
# ortho_hypotension                    2
# vision                               3
# audition                             3
# weight_loss                          2
# exhaustion_score                     2
# raise_chair_time                   277
# balance_single                       3
# gait_get_up                        244
# gait_speed_4m                      222
# gait_optional_binary                 2
# gait_speed_slower                    3
# grip_strength_abnormal               2
# low_physical_activity                2
# falls_one_year                       9
# fractures_three_years                6
# bmi_score                          511
# bmi_body_fat                       150
# waist                               72
# lean_body_mass                     403
# screening_score                      9
# cognitive_total_score               19
# memory_complain                      2
# sleep                                3
# mmse_total_score                     8
# depression_total_score              16
# anxiety_perception                  94
# living_alone                         2
# leisure_out                         25
# leisure_club                         2
# social_visits                       21
# social_calls                        31
# social_phone                        64
# social_skype                        16
# social_text                         32
# house_suitable_participant           2
# house_suitable_professional          2
# stairs_number                       33
# life_quality                        67
# health_rate                          5
# health_rate_comparison               5
# pain_perception                     90
# activity_regular                     4
# smoking                              3
# alcohol_units                       50
# katz_index                           9
# iadl_grade                          24
# comorbidities_count                 18
# comorbidities_significant_count      7
# medication_count                    18
# dtype: int64

# %% [markdown]
# # Preprocessing

# %%
erroneous_dict = {999: np.nan, "test non realizable": np.nan, "Test not adequate": np.nan}

clinical_data_proc = clinical.replace(erroneous_dict)
clinical.head()
# Out:
#    part_id      fried gender  age  hospitalization_one_year  \
# 0     1001  Non frail      F   75                         0
# 1     1002  Pre-frail      M   73                         0
# 2     1003  Pre-frail      M   72                         0
# 3     1004      Frail      F   88                         0
# 4     1005  Pre-frail      F   83                         0
#
#    hospitalization_three_years ortho_hypotension           vision  \
# 0                            0                No  Sees moderately
# 1                            1                No  Sees moderately
# 2                            0                No  Sees moderately
# 3                            0                No  Sees moderately
# 4                            4               Yes  Sees moderately
#
#            audition weight_loss  ...  health_rate_comparison  pain_perception  \
# 0        Hears well          No  ...      3 - About the same              4.2
# 1  Hears moderately          No  ...      2 - A little worse              3.3
# 2  Hears moderately          No  ...      3 - About the same              3.4
# 3  Hears moderately          No  ...      3 - About the same              7.3
# 4      Hears poorly          No  ...      3 - About the same              3.0
#
#            activity_regular                                  smoking  \
# 0  > 2 h and < 5 h per week                             Never smoked
# 1  > 2 h and < 5 h per week                             Never smoked
# 2            < 2 h per week  Past smoker (stopped at least 6 months)
# 3            < 2 h per week                             Never smoked
# 4            > 5 h per week                           Current smoker
#
#    alcohol_units  katz_index iadl_grade comorbidities_count  \
# 0            1.0         6.0       31.0                   5
# 1           14.0         6.0       26.0                  12
# 2           21.0         6.0       26.0                   9
# 3           21.0         5.5       20.0                  11
# 4            0.0         6.0       30.0                  12
#
#   comorbidities_significant_count  medication_count
# 0                               0                 5
# 1                               0                 4
# 2                               0                 3
# 3                               0                 8
# 4                               0                 4
#
# [5 rows x 55 columns]

# %%
labelen = LabelEncoder()
for col in clinical.columns:
    if clinical[col].dtypes == np.object:
        clinical_data_proc[col] = labelen.fit_transform(clinical[col])
# Out:
# /var/folders/p3/0hxxs9qj1dg_s5vjw8zddyw40000gn/T/ipykernel_2982/1006687937.py:3: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if clinical[col].dtypes == np.object:

# %%
pd.set_option("display.max_columns", None)

clinical_data_procnan = clinical_data_proc.dropna(axis = 0)
clinical_data_procnan
# Out:
#      part_id  fried  gender   age  hospitalization_one_year  \
# 0     1001.0      1       0  75.0                       0.0
# 1     1002.0      2       1  73.0                       0.0
# 2     1003.0      2       1  72.0                       0.0
# 4     1005.0      2       0  83.0                       0.0
# 5     1006.0      1       1  72.0                       0.0
# ..       ...    ...     ...   ...                       ...
# 535   3593.0      2       1  75.0                       0.0
# 536   3594.0      1       1  71.0                       0.0
# 537   3600.0      1       0  77.0                       0.0
# 538   3601.0      2       1  84.0                       0.0
# 539   3611.0      1       0  70.0                       0.0
#
#      hospitalization_three_years  ortho_hypotension  vision  audition  \
# 0                            0.0                  0       0         2
# 1                            1.0                  0       0         0
# 2                            0.0                  0       0         0
# 4                            4.0                  1       0         1
# 5                            1.0                  0       0         2
# ..                           ...                ...     ...       ...
# 535                          1.0                  1       2         2
# 536                          0.0                  0       2         2
# 537                          0.0                  0       2         2
# 538                          0.0                  1       2         0
# 539                          0.0                  0       2         2
#
#      weight_loss  exhaustion_score  raise_chair_time  balance_single  \
# 0              0               1.0             13.00               1
# 1              0               1.0             16.00               1
# 2              0               1.0             10.00               1
# 4              0               1.0             13.00               0
# 5              0               1.0             12.00               1
# ..           ...               ...               ...             ...
# 535            0               1.0             14.00               1
# 536            0               1.0             14.80               1
# 537            0               1.0              6.59               1
# 538            0               1.0             11.10               1
# 539            0               1.0              6.60               1
#
#      gait_get_up  gait_speed_4m  gait_optional_binary  gait_speed_slower  \
# 0          18.00           7.00                 False                  0
# 1          60.00          11.00                 False                  2
# 2          21.00          11.00                 False                  2
# 4          42.00           8.00                 False                  2
# 5          18.00           6.00                 False                  0
# ..           ...            ...                   ...                ...
# 535         6.20           2.30                 False                  0
# 536         8.40           2.70                 False                  0
# 537         6.06           2.28                 False                  0
# 538         8.22           2.85                 False                  0
# 539         5.70           2.60                 False                  0
#
#      grip_strength_abnormal  low_physical_activity  falls_one_year  \
# 0                         0                      0             1.0
# 1                         1                      0             1.0
# 2                         1                      0             1.0
# 4                         0                      0             1.0
# 5                         0                      0             0.0
# ..                      ...                    ...             ...
# 535                       1                      0             1.0
# 536                       0                      0             2.0
# 537                       0                      0             0.0
# 538                       1                      0             0.0
# 539                       0                      0             0.0
#
#      fractures_three_years   bmi_score  bmi_body_fat  waist  lean_body_mass  \
# 0                      0.0   27.587326          30.4  101.0         47.3280
# 1                      0.0   25.069362          23.4  109.0         58.1394
# 2                      0.0   34.386317          32.8  122.0         64.4448
# 4                      0.0   25.997436          29.6   88.0         45.6896
# 5                      0.0   25.432526          23.4  100.0         56.3010
# ..                     ...         ...           ...    ...             ...
# 535                    0.0   31.909140          36.3  112.0         60.1328
# 536                    1.0   26.161896          32.3   93.0         51.7905
# 537                    0.0  921.143251          30.0   86.0         44.9400
# 538                    0.0   27.380117          25.3  102.0         67.0059
# 539                    1.0   24.449375          28.0   87.0         42.8400
#
#      screening_score  cognitive_total_score  memory_complain  sleep  \
# 0               14.0                   25.0                0      0
# 1               14.0                   27.0                0      0
# 2               14.0                   26.0                0      1
# 4               12.0                   24.0                1      1
# 5               13.0                   26.0                0      0
# ..               ...                    ...              ...    ...
# 535             11.0                   27.0                0      0
# 536             10.0                   27.0                0      0
# 537             14.0                   21.0                0      2
# 538             14.0                   26.0                0      0
# 539             11.0                   29.0                0      1
#
#      mmse_total_score  depression_total_score  anxiety_perception  \
# 0                30.0                     1.0                 5.0
# 1                28.0                     8.0                 8.2
# 2                27.0                     1.0                 3.4
# 4                27.0                     3.0                 8.2
# 5                29.0                     0.0                 1.0
# ..                ...                     ...                 ...
# 535              27.0                     2.0                 0.0
# 536              29.0                     2.0                 2.4
# 537              27.0                     3.0                 4.0
# 538              28.0                     0.0                 0.0
# 539              29.0                     1.0                 5.2
#
#      living_alone  leisure_out  leisure_club  social_visits  social_calls  \
# 0               1          7.0             1            3.0           7.0
# 1               0          7.0             0            1.0          20.0
# 2               0          7.0             1            5.0          20.0
# 4               1          7.0             1            2.0          10.0
# 5               0         14.0             1            5.0          20.0
# ..            ...          ...           ...            ...           ...
# 535             1          0.0             0            0.0           8.0
# 536             0          5.0             1            4.0           3.0
# 537             1          7.0             0            2.0          20.0
# 538             1         14.0             1            7.0          25.0
# 539             0          7.0             1            6.0           5.0
#
#      social_phone  social_skype  social_text  house_suitable_participant  \
# 0           210.0           0.0          0.0                           1
# 1           140.0           0.0          0.0                           1
# 2           210.0           0.0         10.0                           1
# 4            70.0           0.0          0.0                           1
# 5           420.0           0.0         21.0                           1
# ..            ...           ...          ...                         ...
# 535         240.0           0.0          3.0                           1
# 536          15.0           0.0         30.0                           1
# 537         100.0          30.0          0.0                           1
# 538         250.0           0.0         20.0                           1
# 539          80.0           0.0         40.0                           1
#
#      house_suitable_professional  stairs_number  life_quality  health_rate  \
# 0                              1            0.0           7.4            2
# 1                              1           20.0           7.0            2
# 2                              1            7.0           7.8            3
# 4                              1            0.0           8.4            2
# 5                              1           10.0           9.4            4
# ..                           ...            ...           ...          ...
# 535                            1            0.0          10.0            3
# 536                            1           15.0           8.5            3
# 537                            1            1.0           7.4            3
# 538                            1            0.0           6.5            3
# 539                            1           14.0           5.0            4
#
#      health_rate_comparison  pain_perception  activity_regular  smoking  \
# 0                         2              4.2                 1        1
# 1                         1              3.3                 1        1
# 2                         2              3.4                 0        2
# 4                         2              3.0                 2        0
# 5                         2              0.0                 1        1
# ..                      ...              ...               ...      ...
# 535                       2              1.0                 2        2
# 536                       3              2.0                 2        2
# 537                       1              3.9                 2        1
# 538                       2              4.9                 1        1
# 539                       3              1.0                 2        1
#
#      alcohol_units  katz_index  iadl_grade  comorbidities_count  \
# 0             1.00         6.0        31.0                  5.0
# 1            14.00         6.0        26.0                 12.0
# 2            21.00         6.0        26.0                  9.0
# 4             0.00         6.0        30.0                 12.0
# 5             7.00         6.0        28.0                  5.0
# ..             ...         ...         ...                  ...
# 535           0.00         5.5        31.0                  8.0
# 536          17.25         5.0        28.0                  7.0
# 537           0.50         6.0        31.0                  5.0
# 538          28.00         6.0        31.0                  4.0
# 539           5.25         6.0        31.0                  1.0
#
#      comorbidities_significant_count  medication_count
# 0                                0.0               5.0
# 1                                0.0               4.0
# 2                                0.0               3.0
# 4                                0.0               4.0
# 5                                0.0               6.0
# ..                               ...               ...
# 535                              1.0              10.0
# 536                              0.0               3.0
# 537                              0.0               4.0
# 538                              1.0               8.0
# 539                              0.0               1.0
#
# [266 rows x 55 columns]

# %%
for col in clinical_data_proc.columns:
    clinical_data_proc_filled = clinical_data_proc.fillna(clinical_data_proc[col].median())

clinical_data_proc_filled.groupby(['fried']).size()
# Out:
# fried
# 0    100
# 1    213
# 2    227
# dtype: int64

# %% [markdown]
# # Feature Selection

# %%
variance = np.var(clinical_data_procnan)
variance
# Out:
# part_id                            945304.503604
# fried                                   0.377198
# gender                                  0.238114
# age                                    29.333272
# hospitalization_one_year                1.047431
# hospitalization_three_years             1.572955
# ortho_hypotension                       0.119750
# vision                                  0.904178
# audition                                0.752049
# weight_loss                             0.067344
# exhaustion_score                        0.108669
# raise_chair_time                       30.283047
# balance_single                          0.219699
# gait_get_up                            33.517521
# gait_speed_4m                           6.415189
# gait_optional_binary                    0.088190
# gait_speed_slower                       0.511052
# grip_strength_abnormal                  0.223868
# low_physical_activity                   0.082085
# falls_one_year                          0.705862
# fractures_three_years                   0.217423
# bmi_score                            3012.080969
# bmi_body_fat                           17.169455
# waist                                 156.672579
# lean_body_mass                         77.001536
# screening_score                         2.219416
# cognitive_total_score                   7.821372
# memory_complain                         0.159548
# sleep                                   0.604839
# mmse_total_score                        2.708519
# depression_total_score                  5.877494
# anxiety_perception                      7.110523
# living_alone                            0.239697
# leisure_out                            15.682250
# leisure_club                            0.211784
# social_visits                           6.536449
# social_calls                          155.239234
# social_phone                        36034.739160
# social_skype                         1017.989782
# social_text                           530.868690
# house_suitable_participant              0.032690
# house_suitable_professional             0.046484
# stairs_number                          96.915597
# life_quality                            2.685621
# health_rate                             0.535587
# health_rate_comparison                  0.606719
# pain_perception                         5.494263
# activity_regular                        0.671095
# smoking                                 0.400418
# alcohol_units                          68.374082
# katz_index                              0.098412
# iadl_grade                             17.025510
# comorbidities_count                     7.844720
# comorbidities_significant_count         0.788569
# medication_count                        9.522132
# dtype: float64

# %%
vt = VarianceThreshold(threshold = 0.511)
_ = vt.fit(clinical_data_procnan)

# Get the boolean mask
mask = vt.get_support()

clinical_data_reduced = clinical_data_procnan.loc[:, mask]
clinical_data_reduced
# Out:
#      part_id   age  hospitalization_one_year  hospitalization_three_years  \
# 0     1001.0  75.0                       0.0                          0.0
# 1     1002.0  73.0                       0.0                          1.0
# 2     1003.0  72.0                       0.0                          0.0
# 4     1005.0  83.0                       0.0                          4.0
# 5     1006.0  72.0                       0.0                          1.0
# ..       ...   ...                       ...                          ...
# 535   3593.0  75.0                       0.0                          1.0
# 536   3594.0  71.0                       0.0                          0.0
# 537   3600.0  77.0                       0.0                          0.0
# 538   3601.0  84.0                       0.0                          0.0
# 539   3611.0  70.0                       0.0                          0.0
#
#      vision  audition  raise_chair_time  gait_get_up  gait_speed_4m  \
# 0         0         2             13.00        18.00           7.00
# 1         0         0             16.00        60.00          11.00
# 2         0         0             10.00        21.00          11.00
# 4         0         1             13.00        42.00           8.00
# 5         0         2             12.00        18.00           6.00
# ..      ...       ...               ...          ...            ...
# 535       2         2             14.00         6.20           2.30
# 536       2         2             14.80         8.40           2.70
# 537       2         2              6.59         6.06           2.28
# 538       2         0             11.10         8.22           2.85
# 539       2         2              6.60         5.70           2.60
#
#      gait_speed_slower  falls_one_year   bmi_score  bmi_body_fat  waist  \
# 0                    0             1.0   27.587326          30.4  101.0
# 1                    2             1.0   25.069362          23.4  109.0
# 2                    2             1.0   34.386317          32.8  122.0
# 4                    2             1.0   25.997436          29.6   88.0
# 5                    0             0.0   25.432526          23.4  100.0
# ..                 ...             ...         ...           ...    ...
# 535                  0             1.0   31.909140          36.3  112.0
# 536                  0             2.0   26.161896          32.3   93.0
# 537                  0             0.0  921.143251          30.0   86.0
# 538                  0             0.0   27.380117          25.3  102.0
# 539                  0             0.0   24.449375          28.0   87.0
#
#      lean_body_mass  screening_score  cognitive_total_score  sleep  \
# 0           47.3280             14.0                   25.0      0
# 1           58.1394             14.0                   27.0      0
# 2           64.4448             14.0                   26.0      1
# 4           45.6896             12.0                   24.0      1
# 5           56.3010             13.0                   26.0      0
# ..              ...              ...                    ...    ...
# 535         60.1328             11.0                   27.0      0
# 536         51.7905             10.0                   27.0      0
# 537         44.9400             14.0                   21.0      2
# 538         67.0059             14.0                   26.0      0
# 539         42.8400             11.0                   29.0      1
#
#      mmse_total_score  depression_total_score  anxiety_perception  \
# 0                30.0                     1.0                 5.0
# 1                28.0                     8.0                 8.2
# 2                27.0                     1.0                 3.4
# 4                27.0                     3.0                 8.2
# 5                29.0                     0.0                 1.0
# ..                ...                     ...                 ...
# 535              27.0                     2.0                 0.0
# 536              29.0                     2.0                 2.4
# 537              27.0                     3.0                 4.0
# 538              28.0                     0.0                 0.0
# 539              29.0                     1.0                 5.2
#
#      leisure_out  social_visits  social_calls  social_phone  social_skype  \
# 0            7.0            3.0           7.0         210.0           0.0
# 1            7.0            1.0          20.0         140.0           0.0
# 2            7.0            5.0          20.0         210.0           0.0
# 4            7.0            2.0          10.0          70.0           0.0
# 5           14.0            5.0          20.0         420.0           0.0
# ..           ...            ...           ...           ...           ...
# 535          0.0            0.0           8.0         240.0           0.0
# 536          5.0            4.0           3.0          15.0           0.0
# 537          7.0            2.0          20.0         100.0          30.0
# 538         14.0            7.0          25.0         250.0           0.0
# 539          7.0            6.0           5.0          80.0           0.0
#
#      social_text  stairs_number  life_quality  health_rate  \
# 0            0.0            0.0           7.4            2
# 1            0.0           20.0           7.0            2
# 2           10.0            7.0           7.8            3
# 4            0.0            0.0           8.4            2
# 5           21.0           10.0           9.4            4
# ..           ...            ...           ...          ...
# 535          3.0            0.0          10.0            3
# 536         30.0           15.0           8.5            3
# 537          0.0            1.0           7.4            3
# 538         20.0            0.0           6.5            3
# 539         40.0           14.0           5.0            4
#
#      health_rate_comparison  pain_perception  activity_regular  alcohol_units  \
# 0                         2              4.2                 1           1.00
# 1                         1              3.3                 1          14.00
# 2                         2              3.4                 0          21.00
# 4                         2              3.0                 2           0.00
# 5                         2              0.0                 1           7.00
# ..                      ...              ...               ...            ...
# 535                       2              1.0                 2           0.00
# 536                       3              2.0                 2          17.25
# 537                       1              3.9                 2           0.50
# 538                       2              4.9                 1          28.00
# 539                       3              1.0                 2           5.25
#
#      iadl_grade  comorbidities_count  comorbidities_significant_count  \
# 0          31.0                  5.0                              0.0
# 1          26.0                 12.0                              0.0
# 2          26.0                  9.0                              0.0
# 4          30.0                 12.0                              0.0
# 5          28.0                  5.0                              0.0
# ..          ...                  ...                              ...
# 535        31.0                  8.0                              1.0
# 536        28.0                  7.0                              0.0
# 537        31.0                  5.0                              0.0
# 538        31.0                  4.0                              1.0
# 539        31.0                  1.0                              0.0
#
#      medication_count
# 0                 5.0
# 1                 4.0
# 2                 3.0
# 4                 4.0
# 5                 6.0
# ..                ...
# 535              10.0
# 536               3.0
# 537               4.0
# 538               8.0
# 539               1.0
#
# [266 rows x 38 columns]

# %%
selector = SelectKBest(mutual_info_classif, k=10)
selector.fit(clinical_data_reduced, clinical_data_procnan['fried'])
# Get columns to keep and create new dataframe with those only
cols = selector.get_support(indices=True)
features_df_new = clinical_data_reduced.iloc[:,cols]
features_df_new.drop('gait_speed_slower', axis = 1).columns
# Out:
# Index(['hospitalization_three_years', 'vision', 'gait_get_up', 'waist',
#        'depression_total_score', 'leisure_out', 'pain_perception',
#        'activity_regular', 'comorbidities_count'],
#       dtype='object')

# %% [markdown]
# # Classification

# %%
X = clinical_data_proc_filled[['hospitalization_one_year', 'gait_get_up', 'waist','mmse_total_score', 'social_text', 'health_rate', 'pain_perception','comorbidities_count', 'medication_count']]
# X1 = clinical_data_proc_filled[['depression_total_score', 'health_rate', 'pain_perception', 'activity_regular', 'comorbidities_count']]
y = clinical_data_proc_filled['fried']

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 42)

# %%
knclass = KNeighborsClassifier(n_neighbors= 5).fit(X_train, y_train)
pred1 = knclass.predict(X_test)
pred1
print('Accuracy of K Nearest Neighbors Classifier: {:.5f}'
     .format(knclass.score(X_test, y_test)))
print('Accuracy of K Nearest Neighbors Classifier: {:.5f}'
     .format(knclass.score(X_train, y_train)))
# Out:
# Accuracy of K Nearest Neighbors Classifier: 0.56296
# Accuracy of K Nearest Neighbors Classifier: 0.67654

# %%
svmclas = SVC(gamma = 2, kernel="rbf").fit(X_train, y_train)
pred2 = svmclas.predict(X_test)
print('Accuracy of Support Vector Machine: {:.5f}'
     .format(svmclas.score(X_test, y_test)))
print('Accuracy of Support Vector Machine: {:.5f}'
     .format(svmclas.score(X_train, y_train)))
# Out:
# Accuracy of Support Vector Machine: 0.60000
# Accuracy of Support Vector Machine: 0.65432

# %%
print("Before undersampling: ", Counter(y_train))
undersample = RandomUnderSampler(sampling_strategy='all')

# fit and apply the transform
X_train_under, y_train_under = undersample.fit_resample(X_train, y_train)

# summarize class distribution
print("After undersampling: ", Counter(y_train_under))
# Out:
# Before undersampling:  Counter({2: 174, 1: 160, 0: 71})
# After undersampling:  Counter({0: 71, 1: 71, 2: 71})

# %%
knclass_under = KNeighborsClassifier(n_neighbors= 10).fit(X_train_under, y_train_under)
pred1_under = knclass.predict(X_test)
pred1_under
print('Accuracy of K Nearest Neighbors Classifier: {:.5f}'
     .format(knclass_under.score(X_test, y_test)))
print('Accuracy of K Nearest Neighbors Classifier: {:.5f}'
     .format(knclass_under.score(X_train_under, y_train_under)))
# Out:
# Accuracy of K Nearest Neighbors Classifier: 0.53333
# Accuracy of K Nearest Neighbors Classifier: 0.57531

# %%
# summarize class distribution
print("Before oversampling: ",Counter(y_train))

# define oversampling strategy
SMOTE = RandomOverSampler(sampling_strategy="all", random_state=42)

# fit and apply the transform
X_train_SMOTE, y_train_SMOTE = SMOTE.fit_resample(X_train, y_train)

# summarize class distribution
print("After oversampling: ",Counter(y_train_SMOTE))
# Out:
# Before oversampling:  Counter({2: 174, 1: 160, 0: 71})
# After oversampling:  Counter({2: 174, 1: 174, 0: 174})

# %%
knclass_over = KNeighborsClassifier(n_neighbors= 14).fit(X_train_SMOTE, y_train_SMOTE)
pred1_over = knclass.predict(X_test)
pred1_over
print('Accuracy of K Nearest Neighbors Classifier: {:.5f}'
     .format(knclass_over.score(X_test, y_test)))
print('Accuracy of K Nearest Neighbors Classifier: {:.5f}'
     .format(knclass_under.score(X_train_SMOTE, y_train_SMOTE)))
# Out:
# Accuracy of K Nearest Neighbors Classifier: 0.52593
# Accuracy of K Nearest Neighbors Classifier: 0.60153

# %%
model = SVC(gamma = 0.1, kernel="rbf")
# model = KNeighborsClassifier(n_neighbors= 14)
over = RandomOverSampler(sampling_strategy="not majority", random_state= 42)
under = RandomUnderSampler(sampling_strategy= "all")
steps = [('o', over), ('u', under), ('model', model)]
pipeline = Pipeline(steps=steps)
pipeline.fit(X_train, y_train)
scores = pipeline.score(X_test, y_test)
score_train = pipeline.score(X_train, y_train)
print('ROC AUC score for the combined sampling method: %.5f' % scores)
print('ROC AUC score for the combined sampling method: %.5f' % score_train)
# Out:
# ROC AUC score for the combined sampling method: 0.53333
# ROC AUC score for the combined sampling method: 0.54815

# %% [markdown]
# To do:
#
# 1) Naive Bayes
# 2) Randrom Forest
